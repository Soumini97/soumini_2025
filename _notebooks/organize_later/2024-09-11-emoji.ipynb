# %% [markdown]
# ---
# layout: post
# title: Emoji Notebook
# description: Muahahahaha emojis are amazing 😈
# permalink: /emoji/
# ---

# %%
from emoji import emojize 
print(emojize(":thumbs_up: HI! :grinning_face:"))
# Out:
# 👍 HI! 😀
